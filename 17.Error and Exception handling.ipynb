# %% [markdown]
# ![Screenshot 2024-12-24 at 07.17.12.png](attachment:92be6e41-eed5-43e4-adf3-1522e36ca4b4.png)

# %%
a = 'aaaa'


try:
    parsetoInt = int(a) #blok kode yg akan di check
except:
    print('Error bro variable a bukan angka') # handle error disini
else:
    print(f'angka berhasil di parse! value nya adalah {parsetoInt}') # kalo berhasil disini
finally: 
    print('Terima kasih telah mencoba fungsi validasi') # finnaly akan di run error / success
# Out:
# Error bro variable a bukan angka
# Terima kasih telah mencoba fungsi validasi

# %% [markdown]
# ### specific errors

# %%
a = '12a'

try:
    parsetoInt = ijn(a) #blok kode yg akan di check
    
except ValueError:
    print('Value Error') # handle error disini
except NameError:
    print('Name Error') # handle error disini
# except TypeError:
#     print('SyntaxError Error') # handle error disini
# except RuntimeError:
#     print('RuntimeError Error') # handle error disini
# except TypeError:
#     print('TypeError Error') # handle error disini
    
else:
    print(f'angka berhasil di parse! value nya adalah {parsetoInt}') # kalo berhasil disini
finally: 
    print('Terima kasih telah mencoba fungsi validasi') # finnaly akan di run error / success
# Out:
# Name Error
# Terima kasih telah mencoba fungsi validasi

# %% [markdown]
# ### many except

# %%
a = '12'

try:
    parsetoInt = int(a) #blok kode yg akan di check
    
except (ValueError, NameError): # all error
    print('Value or Name Error') 
    
else:
    print(f'angka berhasil di parse! value nya adalah {parsetoInt}') # kalo berhasil disini
# Out:
# angka berhasil di parse! value nya adalah 12

# %% [markdown]
# ### Define the error to string

# %%
a = '12a'

try:
    parsetoInt = int(a) #blok kode yg akan di check
    
except Exception as err: # all error
    print(f'errornya ini = {err}') 
    
else:
    print(f'angka berhasil di parse! value nya adalah {parsetoInt}') # kalo berhasil disini
# Out:
# errornya ini = invalid literal for int() with base 10: '12a'
